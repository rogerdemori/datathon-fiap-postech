# %%
import pandas as pd

# %%
df = pd.read_excel('/content/tx_rend_municipios_2022.xlsx', skiprows=7)

# %%
df.head()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2    Unnamed: 3             Unnamed: 4  \
# 0  NU_ANO_CENSO  NO_REGIAO      SG_UF  CO_MUNICIPIO           NO_MUNICIPIO
# 1          2022      Norte         RO       1100015  Alta Floresta D'Oeste
# 2          2022      Norte         RO       1100015  Alta Floresta D'Oeste
# 3          2022      Norte         RO       1100015  Alta Floresta D'Oeste
# 4          2022      Norte         RO       1100015  Alta Floresta D'Oeste
#
#      Unnamed: 5      Unnamed: 6      Total Anos Iniciais   Anos Finais  ...  \
# 0  NO_CATEGORIA  NO_DEPENDENCIA  1_CAT_FUN  1_CAT_FUN_AI  1_CAT_FUN_AF  ...
# 1         Total           Total       91.9          91.6          92.2  ...
# 2        Urbana           Total         93          92.5          93.4  ...
# 3         Rural           Total       87.1          87.7          86.5  ...
# 4         Total        Estadual       92.1          84.3          93.5  ...
#
# ...

# %%
municipios_desejados = ['Embu-Guaçu', 'Cipó-Guaçu', 'São Lourenço da Serra', 'Itapecerica da Serra']
df = df[df['Unnamed: 4'].isin(municipios_desejados)]

# %%
df
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3             Unnamed: 4  \
# 41907       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41908       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41909       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41910       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41911       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41912       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41913       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41914       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41915       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41916       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41917       2022    Sudeste         SP    3515103             Embu-Guaçu
# 41918       2022    Sudeste         SP    3515103             Embu-Guaçu
# ...

# %%
nomes_colunas = {
    'Unnamed: 0': 'Ano',
    'Unnamed: 1': 'Região',
    'Unnamed: 2': 'UF',
    'Unnamed: 3': 'Código do Município',
    'Unnamed: 4': 'Nome do Município',
    'Unnamed: 5': 'Localização',
    'Unnamed: 6': 'Dependência Administrativa'}

# %%
df = df.rename(columns=nomes_colunas)

# %%
df
# Out:
#         Ano   Região  UF Código do Município      Nome do Município  \
# 41907  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41908  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41909  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41910  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41911  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41912  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41913  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41914  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41915  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41916  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41917  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41918  2022  Sudeste  SP             3515103             Embu-Guaçu
# 41919  2022  Sudeste  SP             3515103             Embu-Guaçu
# ...

# %%
# Reinicializando os índices após a remoção da linha
df = df.reset_index(drop=True)

# %%
df
# Out:
#      Ano   Região  UF Código do Município      Nome do Município Localização  \
# 0   2022  Sudeste  SP             3515103             Embu-Guaçu       Total
# 1   2022  Sudeste  SP             3515103             Embu-Guaçu      Urbana
# 2   2022  Sudeste  SP             3515103             Embu-Guaçu       Rural
# 3   2022  Sudeste  SP             3515103             Embu-Guaçu       Total
# 4   2022  Sudeste  SP             3515103             Embu-Guaçu      Urbana
# 5   2022  Sudeste  SP             3515103             Embu-Guaçu       Total
# 6   2022  Sudeste  SP             3515103             Embu-Guaçu      Urbana
# 7   2022  Sudeste  SP             3515103             Embu-Guaçu       Rural
# 8   2022  Sudeste  SP             3515103             Embu-Guaçu       Total
# 9   2022  Sudeste  SP             3515103             Embu-Guaçu      Urbana
# 10  2022  Sudeste  SP             3515103             Embu-Guaçu       Rural
# ...

# %%
df.isnull().sum()
# Out:
# Ano                    0
# Região                 0
# UF                     0
# Código do Município    0
# Nome do Município      0
#                       ..
# 1ª série.2             0
# 2ª série.2             0
# 3ª série.2             0
# 4ª série.2             0
# Não-Seriado.2          0
# Length: 61, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 61 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Ano                         37 non-null     object
#  1   Região                      37 non-null     object
#  2   UF                          37 non-null     object
#  3   Código do Município         37 non-null     object
#  4   Nome do Município           37 non-null     object
#  5   Localização                 37 non-null     object
#  6   Dependência Administrativa  37 non-null     object
#  7   Total                       37 non-null     object
#  8   Anos Iniciais               37 non-null     object
#  9   Anos Finais                 37 non-null     object
#  10  1º Ano                      37 non-null     object
#  11  2º Ano                      37 non-null     object
#  12  3º Ano                      37 non-null     object
# ...

# %%
df_novo = df_novo.loc[(df['Localização'] == 'Total') & (df['Dependência Administrativa'] == 'Total')]

# %%
df_novo
# Out:
#      Ano   Região  UF Código do Município      Nome do Município Localização  \
# 0   2022  Sudeste  SP             3515103             Embu-Guaçu       Total
# 14  2022  Sudeste  SP             3522208   Itapecerica da Serra       Total
# 24  2022  Sudeste  SP             3549953  São Lourenço da Serra       Total
#
#    Dependência Administrativa Total Total.1 Total.2
# 0                       Total  99.7     0.2     0.1
# 14                      Total    98     1.7     0.3
# 24                      Total  99.6     0.4       0

# %%
colunas_desejadas = ["Ano", "Região", "UF", "Código do Município", "Nome do Município", "Localização", "Dependência Administrativa", "Total", "Total.1", "Total.2"]
df_novo = df_novo[colunas_desejadas]

# %%
df_novo
# Out:
#      Ano   Região  UF Código do Município      Nome do Município Localização  \
# 0   2022  Sudeste  SP             3515103             Embu-Guaçu       Total
# 14  2022  Sudeste  SP             3522208   Itapecerica da Serra       Total
# 24  2022  Sudeste  SP             3549953  São Lourenço da Serra       Total
#
#    Dependência Administrativa Total Total.1 Total.2
# 0                       Total  99.7     0.2     0.1
# 14                      Total    98     1.7     0.3
# 24                      Total  99.6     0.4       0

# %%
novos_nomes = {
    'Total': 'Taxa de Aprovação',
    'Total.1': 'Taxa de Reprovação',
    'Total.2': 'Taxa de Reprovação'
}
df_novo = df_novo.rename(columns=novos_nomes)

# %%
df_novo
# Out:
#      Ano   Região  UF Código do Município      Nome do Município Localização  \
# 0   2022  Sudeste  SP             3515103             Embu-Guaçu       Total
# 14  2022  Sudeste  SP             3522208   Itapecerica da Serra       Total
# 24  2022  Sudeste  SP             3549953  São Lourenço da Serra       Total
#
#    Dependência Administrativa Taxa de Aprovação Taxa de Reprovação  \
# 0                       Total              99.7                0.2
# 14                      Total                98                1.7
# 24                      Total              99.6                0.4
#
#    Taxa de Reprovação
# 0                 0.1
# 14                0.3
# 24                  0

# %%
caminho_arquivo = r'INEP_Taxa_de_Rendimento.csv'

# Salvando o DataFrame em um arquivo CSV
df_novo.to_csv(caminho_arquivo, index=False)  # index=False para não incluir os índices no arquivo CSV

print(f"DataFrame salvo em: {caminho_arquivo}")
# Out:
# DataFrame salvo em: INEP_Taxa_de_Rendimento.csv
